# %%
with open('2315_possible_answers.txt') as fh:
    answer  = fh.readlines()
answer = [line.rstrip('\n') for line in answer]

with open('2315_possible_answers.txt') as fh:
    answer  = fh.readlines()
allowed = [line.rstrip('\n') for line in answer]

# %%
import random
import re
import string
import pandas as pd

class Wardle(object):

    def __init__(self):
        with open('2315_possible_answers.txt') as fh:
            answer  = fh.readlines()
        self.answer = [line.rstrip('\n') for line in answer]

        #print('{0} words added on answer'.format(len(self.answer)))

        with open('12972_allowed_words.txt') as fh:
            allowed  = fh.readlines()
        self.allowed = [line.rstrip('\n') for line in allowed]
        self.allowed_proba = self.createProb(self.allowed )

        #print('{0} words added on allowed'.format(len(self.allowed)))

        self.word = self.wordleWord()
        self.guess_left = 0


        self.passed = self.allowed
        self.gray = ""
        self.green = set()
        self.yellow = ""

        self.wordScores,self.total =  self.calWordScore(self.allowed)
        
        print("Today's Word is *** {0} ***".format(self.word.upper()))

    def createProb(self,wordList):
        l = len(wordList)
        return [1/l] * l
    
    def calWordScore(self,allowed):
        frequency = { ch : [0] * 5 for ch in string.ascii_lowercase}
        for word in allowed:
            for i in range(0,5):
                frequency[word[i]][i] += 1
        
        words = {}
        maxFreq = [0] * 5
        for ch in frequency:
            for i in range(0,5):
                if maxFreq[i] < frequency[ch][i]:
                    maxFreq[i] = frequency[ch][i]
        total = 0
        for word in allowed:
            score  = 1
            for i in range(0,5):
                ch = word[i]
                score =  maxFreq[i] - maxFreq[i]
            words.update({word: score})
            total += score
        #return words,total
        return frequency,0

    def wordProb(self):
        total = self.total
        words = self.wordScores
        allowed = self.passed

        prob = []
        passed = []
        for word in allowed:

            prob.append(1 - (1/(1 + np.exp(-words[word]))))
            #prob.append(1 - words[word]/total)
            passed.append(word)
        
        return prob, passed

    def wordleWord(self):
        return random.choice(self.answer)

    def startGuess(self):
        wght,words = self.wordProb()
        guess = random.choices(words, weights = wght, k= 1)[0]
        #guess = random.choice(list(self.passed))
        self.guess_left += 1
        print("{0}".format(guess.upper()))
        self.output(guess)

    def output(self,word):
        for chG,chW in zip(word, self.word):
            if chG == chW:
                self.green.add((chW,self.word.index(chW)))
            if chG not in self.word:
                self.gray += chG
            else:
                if chW not in word :
                    self.yellow += chG
        #print(self.gray,self.green,self.yellow,sep='\n')

    def check(self,str, pattern):
        if re.search(pattern, str):
            return True
        else:
            return False

    def chrPresent(self,chrList):
        l = len(self.passed)
        allowed = self.passed
        if chrList == "":
            self.passed = allowed
            return None
        pattern = re.compile('[{0}]'.format(chrList))
        passed = []
        for word in allowed:
            if self.check(word, pattern):
                passed.append(word)
        self.passed = passed
        #print(self.yellow)
        #print(100 - round(len(self.passed)/l,3) * 100)

    def chrNotPresent(self,chrList):
        l = len(self.passed)
        allowed = self.passed
        pattern = re.compile('[{0}]'.format(chrList))
        passed = []
        for word in allowed:
            if not self.check(word, pattern):
                passed.append(word)
        self.passed = passed
        #print(self.gray)
        #print(100 - round(len(self.passed)/l,3) * 100)
    
    def location(self,greenList,allowed):
        passed = set()
        if greenList == []:
            return allowed
        else:
            ch, loc = greenList[0]
            for word in allowed:
                if word[loc] == ch:
                    passed.add(word)
            return self.location(greenList[1:],list(passed))
    
    def chrLocation(self,greenList):
        l = len(self.passed)
        greenList = list(greenList)
        self.passed = self.location(greenList,self.passed)
        #print(self.green)
        #print(100 - round(len(self.passed)/l,3) * 100)

# %%
game = Wardle()
matrix  = pd.DataFrame( game.wordScores).T
d = matrix/matrix.sum(axis =0)
d.T.to_dict()
# Out:
# Today's Word is *** STUDY ***
# 0.05681467776749923

# %%
count = 0
for i in range(100):
    game =  Wardle()
    while len(game.passed) > 1 and  game.guess_left < 6:
        game.startGuess()


        game.chrLocation(game.green)
        game.chrPresent(game.yellow)
        game.chrNotPresent(game.gray)

        if len(game.passed) == 1:
            #print(game.passed[0].upper())
            #print("competed in {0} trail".format(game.guess_left))
            count += 1
            break

print("accuracy:",count/100)
# Out:
# Today's Word is *** HYMEN ***
# GOTHS
# AAHED
# WHEEN
# HEBEN
# HYMEN
# Today's Word is *** HIPPY ***
# KIDDY
# FILLY
# ZINCY
# JIMMY
# HISSY
# Today's Word is *** VOCAL ***
# DIVNA
# SHAUL
# TEPAL
# CRAAL
# COXAL
# VOCAL
# Today's Word is *** QUASH ***
# ANTAR
# GLIAS
# SCAFF
# ODAHS
# QUAKY
# QUASH
# Today's Word is *** GRAVY ***
# SMELL
# CHIRR
# BURKA
# DRYAD
# PRATY
# Today's Word is *** OTTER ***
# IGLOO
# OKEHS
# ORMER
# OFFER
# OWNER
# OTTER
# Today's Word is *** FARCE ***
# SCALY
# VOEMA
# AWARD
# CRARE
# CRARE
# ARGUE
# Today's Word is *** CLINK ***
# TEGGS
# OIDIA
# CLIMB
# CLICK
# CLICK
# CLICK
# Today's Word is *** SHAKE ***
# KORMA
# VATUS
# KIPES
# HECKS
# NABKS
# KEEKS
# Today's Word is *** CHECK ***
# GAUNT
# SLOPS
# CIVIE
# CERED
# CHEWY
# CHEEK
# Today's Word is *** GROAN ***
# NUKED
# BINAL
# COTAN
# HAZAN
# MAYAN
# ORGAN
# Today's Word is *** UNTIE ***
# CELLA
# WENTS
# GYBED
# QUOTE
# NIXIE
# PENIE
# Today's Word is *** PUDGY ***
# PIPAS
# POUCH
# PUFFY
# PUDDY
# PUDDY
# PUDDY
# Today's Word is *** KNOLL ***
# GAMED
# CHOLO
# FOOLS
# OBOLI
# TROLL
# KNOLL
# Today's Word is *** FILLY ***
# TEAMS
# YUCKO
# BLINY
# GYPPY
# WILLY
# DILLY
# Today's Word is *** LEFTY ***
# ACORN
# PUTTY
# FELTY
# FELTY
# KELTY
# TESTY
# Today's Word is *** LINGO ***
# SAUGH
# GORGE
# MOGGY
# BINGO
# DINGO
# LINGO
# Today's Word is *** ADULT ***
# MARMS
# FADED
# CALID
# NAVAL
# TABBY
# LOATH
# Today's Word is *** RISKY ***
# CHUGS
# NARES
# SPOOF
# TWIST
# BILKS
# DISKS
# Today's Word is *** OCTET ***
# LEISH
# RENTE
# PAYED
# TUTEE
# TOTEM
# Today's Word is *** DOWRY ***
# LAIRD
# DRERE
# DORRS
# DOWRY
# Today's Word is *** PHONE ***
# SKYRE
# JOULE
# POMBE
# PODGE
# PHONE
# Today's Word is *** GECKO ***
# OWLED
# TORUS
# BEKAH
# VEGIE
# FENNY
# MEZZE
# Today's Word is *** CRUDE ***
# LEUCO
# TRUER
# DRUSE
# DRUPE
# CRUVE
# Today's Word is *** LURID ***
# COPPY
# WIZES
# NIVAL
# BRITT
# GUILD
# HUMID
# Today's Word is *** WORTH ***
# TABBY
# ROTIS
# ROUTE
# TOOTH
# FOWTH
# ROWTH
# Today's Word is *** SHINE ***
# PUNKA
# EOSIN
# DJINN
# EZINE
# GWINE
# IMINE
# Today's Word is *** CATER ***
# SOUCT
# MEDIC
# THEGN
# CRAAL
# CRAPY
# CATER
# Today's Word is *** TONIC ***
# ETHER
# ALIST
# BOXTY
# NOINT
# CONTO
# CONTO
# Today's Word is *** COVEN ***
# DIMBO
# PONTS
# WORRY
# LOAVE
# COGUE
# COOEE
# Today's Word is *** TONAL ***
# JONGS
# MONAL
# TONAL
# Today's Word is *** OPIUM ***
# PEASE
# HIPPO
# TYPIC
# LUPIN
# POORI
# UPBOW
# Today's Word is *** SCONE ***
# TRUNK
# FOINS
# LEONE
# SHONE
# Today's Word is *** DRIED ***
# WANKS
# UTTER
# PLYER
# RODEO
# DIVER
# DREER
# Today's Word is *** DICEY ***
# CHIRT
# BLOCS
# DINIC
# DICED
# DICEY
# Today's Word is *** FORGE ***
# PREED
# EYRAS
# CORER
# HORME
# OORIE
# FORTE
# Today's Word is *** SLEEK ***
# AMNIA
# GESTS
# DELPH
# CREEK
# FLEEK
# Today's Word is *** POESY ***
# MEMOS
# SOWED
# TOGES
# SONNE
# BOILS
# SORRA
# Today's Word is *** SEVER ***
# GAWPS
# CONKS
# MUSTH
# BYDES
# LEVES
# Today's Word is *** LUCID ***
# PREES
# BWAZI
# DOLCI
# LIMIT
# LUDIC
# LUDIC
# Today's Word is *** BIDDY ***
# SAFES
# BLIMP
# BINGO
# BIDDY
# Today's Word is *** DROSS ***
# SKLIM
# AZANS
# GORSY
# BRUST
# DRESS
# Today's Word is *** BURST ***
# CORPS
# TURMS
# LURES
# SURAT
# HURST
# BURST
# Today's Word is *** FLINT ***
# TUPIK
# STAFF
# WETLY
# BRITT
# CLINT
# FLINT
# Today's Word is *** BRIBE ***
# WHEAR
# SOLVE
# BRIZE
# BRIDE
# BRIBE
# BRINE
# Today's Word is *** WOUND ***
# MOILE
# QOPHS
# COACT
# VODDY
# DOBRO
# FONDU
# Today's Word is *** RUGBY ***
# DAWDS
# BROME
# VIZIR
# CRUCK
# PURTY
# HURLY
# Today's Word is *** PIECE ***
# KORAT
# MULEY
# EPEES
# PIECE
# Today's Word is *** DEVIL ***
# SPATS
# CYBER
# WIDEN
# DEFOG
# DELED
# DEVIL
# Today's Word is *** TRIAD ***
# HURLY
# ZORRO
# SIRRA
# REATE
# WRAPT
# BRAND
# Today's Word is *** STUNT ***
# BROIL
# SCENT
# STANG
# STUNS
# STUNS
# STUNK
# Today's Word is *** HOTEL ***
# SWAMY
# BOLIX
# LOUND
# LOVER
# Today's Word is *** SWING ***
# REHAB
# OXIDS
# TWIGS
# SWISS
# SWILL
# SWING
# Today's Word is *** STOKE ***
# PUZEL
# TECHY
# WASTE
# KENTE
# SEDGE
# SEMEE
# Today's Word is *** SQUAT ***
# SHUCK
# SLUED
# SAURY
# SQUAW
# SQUAB
# Today's Word is *** ELDER ***
# MEFFS
# HEJAB
# PETER
# ERROR
# EDGER
# ELDER
# Today's Word is *** JOIST ***
# BUMPS
# SAROD
# SYCES
# FILOS
# SHOWS
# KNOTS
# Today's Word is *** DEPTH ***
# AGILE
# MECKS
# DEEVE
# DERNY
# DEPOT
# Today's Word is *** ARGUE ***
# CAWED
# BOTEL
# HAAFS
# MARRY
# KREEP
# AREAE
# Today's Word is *** SEMEN ***
# HACEK
# LEXES
# BESTS
# WEENS
# EENSY
# DERVS
# Today's Word is *** SLATE ***
# SHEOL
# STEAD
# SPUES
# SWIVE
# SENTE
# SKYTE
# Today's Word is *** BLOAT ***
# REPEL
# FLISK
# CLOUT
# GLOAT
# Today's Word is *** BATHE ***
# TYLER
# DOEST
# TITCH
# GETUP
# HATHA
# BATHE
# Today's Word is *** GUILE ***
# SNEED
# GUILE
# Today's Word is *** CAPER ***
# ZARFS
# LAHAR
# RAWER
# GAPER
# RAPER
# CAPER
# Today's Word is *** KNEEL ***
# LIVID
# NABLA
# LOFTY
# PULSE
# ELMEN
# CLECK
# Today's Word is *** RETRO ***
# KEMPT
# SENTI
# DEALT
# FECHT
# REVET
# RETOX
# Today's Word is *** BOBBY ***
# STAPS
# ENDUE
# FILLY
# BOOZY
# BOOGY
# BOOKY
# Today's Word is *** PRIED ***
# CISSY
# UNDID
# GEOID
# HIVED
# LIMED
# BIPED
# Today's Word is *** CONIC ***
# TIMPS
# VINEW
# CONIC
# CONIA
# CONIC
# CONIC
# Today's Word is *** GLINT ***
# ICTAL
# HOMIE
# DJINN
# RUINS
# BLINK
# FLINT
# Today's Word is *** SCAMP ***
# FLYPE
# PHUTS
# ROMPS
# PAPPI
# SWAMP
# Today's Word is *** MINCE ***
# PISSY
# KIORE
# NICHE
# LIANE
# MINGE
# Today's Word is *** LYNCH ***
# SHEET
# UHURU
# LYNCH
# Today's Word is *** GUSTO ***
# REAME
# UNFIT
# PLUTO
# GUSTO
# Today's Word is *** WHEAT ***
# SAUTS
# ALOWE
# CARVY
# DAGGA
# NEAFE
# MAMEE
# Today's Word is *** BROAD ***
# GYROS
# DOLED
# BOUND
# BOVID
# BOORD
# BROOD
# Today's Word is *** KAYAK ***
# THEED
# BOSOM
# RUGGY
# KYLIX
# KYACK
# Today's Word is *** CREDO ***
# VOGUE
# PORAL
# OBIIT
# SORER
# KENDO
# FORDO
# Today's Word is *** LATHE ***
# CAREX
# EANED
# WAWES
# FAVEL
# MAZEY
# LABEL
# Today's Word is *** MECCA ***
# SPARD
# HAULT
# MAMMA
# MANGA
# MYOMA
# MAMBA
# Today's Word is *** VISOR ***
# EARLS
# RUMPY
# FROND
# BROCK
# TORII
# VROWS
# Today's Word is *** CHAIN ***
# SLIMY
# CRIED
# COBIA
# CHAIN
# Today's Word is *** PADDY ***
# GOSSE
# CRAZY
# FAFFY
# TALLY
# HANDY
# WADDY
# Today's Word is *** TAFFY ***
# VETCH
# ROTOS
# LITAI
# MANTY
# TAGGY
# TATTY
# Today's Word is *** ALIVE ***
# AORTA
# ANIME
# AGILE
# AZIDE
# ALIKE
# Today's Word is *** VYING ***
# ZEXES
# GHOUL
# JIRGA
# PYGMY
# NYING
# VYING
# Today's Word is *** TRIAL ***
# ALANT
# BATCH
# GURLY
# FORZA
# VIVAS
# MALAX
# Today's Word is *** BOBBY ***
# MICOS
# ATONE
# BOGGY
# BOODY
# BOOBY
# BOOFY
# Today's Word is *** GECKO ***
# OSHAC
# DETOX
# PEEOY
# BEROB
# GENOM
# Today's Word is *** FOIST ***
# ELUTE
# TICCA
# GRIPT
# MOIST
# JOIST
# FOIST
# Today's Word is *** POKER ***
# CAUSA
# TITRE
# GOOKY
# ROKED
# KOKER
# POKER
# Today's Word is *** INGOT ***
# LEACH
# BRUST
# POINT
# INWIT
# INGOT
# Today's Word is *** ROUND ***
# MANIC
# SHENT
# FLONG
# WOUND
# BOUND
# ROUND
# Today's Word is *** OFFER ***
# NEUME
# DEKES
# ROGER
# FAVER
# OWLER
# OXTER
# Today's Word is *** ROUGE ***
# DRACK
# PRIMY
# ROVEN
# ROTLS
# ROGER
# ROUGH
# Today's Word is *** IRONY ***
# PSEUD
# MICKY
# BILBY
# IVORY
# Today's Word is *** CREEK ***
# IHRAM
# PRONG
# DREES
# CREEL
# CREEK
# Today's Word is *** ADORN ***
# ROVED
# INTRA
# BOARS
# DOORN
# ACORN
# Today's Word is *** BURST ***
# CARPI
# SERRS
# SORUS
# MURRS
# QURSH
# BURST
# accuracy: 0.57

# %%
game =  Wardle()
# Out:
# Today's Word is *** SCORE ***

# %%
game.startGuess()
l = len(game.passed)
game.chrLocation(game.green)
game.chrPresent(game.yellow)
game.chrNotPresent(game.gray)
len(game.passed)/l
# Out:
# SCORE
# {('c', 1), ('o', 2), ('s', 0), ('r', 3), ('e', 4)}
# sesoeees
# tiadhunlmbywp
# 1.0

# %%
# Out:
# ['becks',
#  'bedes',
#  'beefs',
#  'beeps',
#  'beers',
#  'bells',
#  'bends',
#  'benes',
#  'beres',
#  'bergs',
#  'berks',
#  'berms',
#  'besee',
#  'beses',
#  'besom',
#  'bezes',
#  'bhels',
#  'blebs',
#  'blees',
#  'bless',
#  'bleys',
#  'blobs',
#  'blocs',
#  'blogs',
#  'blows',
#  'blubs',
#  'bluds',
#  'blues',
#  'blurs',
#  'blush',
#  'bobos',
#  'bocks',
#  'bodes',
#  'boeps',
#  'boffs',
#  'bogus',
#  'bohos',
#  'bokes',
#  'bokos',
#  'bolds',
#  'boles',
#  'bolls',
#  'bolos',
#  'bolus',
#  'bombs',
#  'bonds',
#  'bones',
#  'bongs',
#  'bonks',
#  'bonus',
#  'boobs',
#  'boohs',
#  'books',
#  'bools',
#  'booms',
#  'boons',
#  'boors',
#  'boose',
#  'bords',
#  'bores',
#  'borks',
#  'borms',
#  'bosks',
#  'bosky',
#  'bosom',
#  'boson',
#  'bossy',
#  'bosun',
#  'bouks',
#  'bouns',
#  'bouse',
#  'bousy',
#  'bowes',
#  'bowls',
#  'bowrs',
#  'bowse',
#  'boxes',
#  'boyfs',
#  'boygs',
#  'boyos',
#  'boysy',
#  'bozos',
#  'breds',
#  'brees',
#  'brens',
#  'brers',
#  'brews',
#  'breys',
#  'brods',
#  'brogs',
#  'broos',
#  'brose',
#  'brosy',
#  'brows',
#  'brush',
#  'brusk',
#  'bubus',
#  'bucks',
#  'budos',
#  'buffs',
#  'bufos',
#  'buhls',
#  'buhrs',
#  'bukes',
#  'bulbs',
#  'bulks',
#  'bulls',
#  'bulse',
#  'bumfs',
#  'bumps',
#  'bunds',
#  'bungs',
#  'bunks',
#  'bunns',
#  'buoys',
#  'burbs',
#  'burds',
#  'burgs',
#  'burks',
#  'burls',
#  'burns',
#  'burps',
#  'burrs',
#  'burse',
#  'busby',
#  'bused',
#  'buses',
#  'bushy',
#  'busks',
#  'busky',
#  'bussu',
#  'bydes',
#  'bykes',
#  'byres',
#  'byrls',
#  'cedes',
#  'cells',
#  'cense',
#  'cepes',
#  'ceres',
#  'ceros',
#  'cesse',
#  'chefs',
#  'chems',
#  'chess',
#  'chews',
#  'chocs',
#  'chogs',
#  'chons',
#  'chops',
#  'chose',
#  'chows',
#  'chubs',
#  'chugs',
#  'chums',
#  'chuse',
#  'clefs',
#  'clegs',
#  'clems',
#  'clews',
#  'clods',
#  'clogs',
#  'clons',
#  'clops',
#  'close',
#  'clous',
#  'clows',
#  'cloys',
#  'clubs',
#  'clues',
#  'cobbs',
#  'cocks',
#  'cocos',
#  'codes',
#  'coeds',
#  'coffs',
#  'cohos',
#  'cokes',
#  'colds',
#  'coles',
#  'colls',
#  'combs',
#  'comes',
#  'comms',
#  'comps',
#  'comus',
#  'cones',
#  'confs',
#  'conks',
#  'conns',
#  'conus',
#  'coofs',
#  'cooks',
#  'cools',
#  'cooms',
#  'coons',
#  'coops',
#  'copes',
#  'copse',
#  'copsy',
#  'cords',
#  'cores',
#  'corks',
#  'corms',
#  'corns',
#  'corps',
#  'corse',
#  'corso',
#  'cosec',
#  'cosed',
#  'coses',
#  'cosey',
#  'coups',
#  'cours',
#  'coves',
#  'cowks',
#  'cowls',
#  'cowps',
#  'coxes',
#  'cozes',
#  'creds',
#  'crees',
#  'crems',
#  'creps',
#  'cress',
#  'crews',
#  'crocs',
#  'crogs',
#  'crons',
#  'crops',
#  'cross',
#  'crows',
#  'cruds',
#  'crues',
#  'cruse',
#  'crush',
#  'crusy',
#  'cubes',
#  'cuffs',
#  'cukes',
#  'culls',
#  'culms',
#  'curbs',
#  'curds',
#  'cures',
#  'curfs',
#  'curls',
#  'curns',
#  'currs',
#  'curse',
#  'cusec',
#  'cushy',
#  'cusks',
#  'cusps',
#  'cuspy',
#  'cusso',
#  'cusum',
#  'cuzes',
#  'cymes',
#  'debes',
#  'debus',
#  'decks',
#  'decos',
#  'deeds',
#  'deems',
#  'deens',
#  'deeps',
#  'deers',
#  'deevs',
#  'degus',
#  'dekes',
#  'deles',
#  'delfs',
#  'dells',
#  'delos',
#  'demes',
#  'demos',
#  'denes',
#  'dense',
#  'deres',
#  'derms',
#  'derns',
#  'deros',
#  'dervs',
#  'desex',
#  'desks',
#  'desse',
#  'devos',
#  'dexes',
#  'dhols',
#  'dhows',
#  'dobes',
#  'docks',
#  'docos',
#  'docus',
#  'dodos',
#  'doeks',
#  'doers',
#  'doffs',
#  'doges',
#  'dojos',
#  'doles',
#  'dolls',
#  'dolos',
#  'domes',
#  'dongs',
#  'donsy',
#  'doobs',
#  'dooks',
#  'dools',
#  'dooms',
#  'doors',
#  'dopes',
#  'dorbs',
#  'dores',
#  'dorks',
#  'dorms',
#  'dorps',
#  'dorrs',
#  'dorse',
#  'dosed',
#  'doseh',
#  'doser',
#  'doses',
#  'doucs',
#  'douks',
#  'doums',
#  'doups',
#  'douse',
#  'doves',
#  'dowds',
#  'dowls',
#  'downs',
#  'dowps',
#  'dowse',
#  'doxes',
#  'dozes',
#  'drees',
#  'dregs',
#  'dreks',
#  'dress',
#  'dreys',
#  'drops',
#  'dross',
#  'drows',
#  'drubs',
#  'drugs',
#  'drums',
#  'druse',
#  'drusy',
#  'dsobo',
#  'dsomo',
#  'duces',
#  'ducks',
#  'dudes',
#  'duels',
#  'duffs',
#  'dufus',
#  'dukes',
#  'dules',
#  'dulls',
#  'dulse',
#  'dumbs',
#  'dumps',
#  'dunes',
#  'dungs',
#  'dunks',
#  'dunsh',
#  'dupes',
#  'dures',
#  'durns',
#  'duros',
#  'durrs',
#  'dusks',
#  'dusky',
#  'duxes',
#  'dyers',
#  'dykes',
#  'dynes',
#  'dzhos',
#  'ebons',
#  'eches',
#  'echos',
#  'ecrus',
#  'edges',
#  'eensy',
#  'eevns',
#  'egers',
#  'elops',
#  'elves',
#  'embus',
#  'emeus',
#  'emmys',
#  'emyds',
#  'enews',
#  'enols',
#  'enows',
#  'ensew',
#  'ensky',
#  'ensue',
#  'eorls',
#  'epees',
#  'eques',
#  'erevs',
#  'ergos',
#  'erhus',
#  'ernes',
#  'erose',
#  'erses',
#  'eruvs',
#  'esker',
#  'esnes',
#  'esses',
#  'eughs',
#  'euros',
#  'eusol',
#  'evens',
#  'ewers',
#  'execs',
#  'exons',
#  'expos',
#  'exuls',
#  'eyers',
#  'eyres',
#  'feces',
#  'fecks',
#  'feebs',
#  'feeds',
#  'feels',
#  'feens',
#  'feers',
#  'feese',
#  'fells',
#  'femes',
#  'fends',
#  'fenks',
#  'feods',
#  'feres',
#  'ferms',
#  'ferns',
#  'fesse',
#  'feuds',
#  'fezes',
#  'flees',
#  'flegs',
#  'flesh',
#  'flews',
#  'fleys',
#  'flobs',
#  'flocs',
#  'floes',
#  'flogs',
#  'flops',
#  'flors',
#  'flosh',
#  'floss',
#  'flows',
#  'flubs',
#  'flues',
#  'flush',
#  'focus',
#  'fohns',
#  'folds',
#  'folks',
#  'fomes',
#  'fonds',
#  'fones',
#  'foods',
#  'fools',
#  'forbs',
#  'fords',
#  'fores',
#  'forks',
#  'forms',
#  'fosse',
#  'fouds',
#  'fouls',
#  'fours',
#  'fowls',
#  'foxes',
#  'frees',
#  'fresh',
#  'froes',
#  'frogs',
#  'frons',
#  'frosh',
#  'frows',
#  'frugs',
#  'frush',
#  'fubsy',
#  'fucks',
#  'fucus',
#  'fuels',
#  'fuffs',
#  'fugus',
#  'fulls',
#  'fumes',
#  'funds',
#  'fungs',
#  'funks',
#  'furls',
#  'furrs',
#  'fused',
#  'fusee',
#  'fusel',
#  'fuses',
#  'fusks',
#  'fussy',
#  'fuzes',
#  'fyces',
#  'fykes',
#  'fyles',
#  'fyrds',
#  'gecks',
#  'geeks',
#  'geeps',
#  'geese',
#  'gelds',
#  'genes',
#  'genus',
#  'geres',
#  'germs',
#  'gesse',
#  'gesso',
#  'geums',
#  'ghees',
#  'gleds',
#  'glees',
#  'glens',
#  'gleys',
#  'globs',
#  'gloms',
#  'glops',
#  'gloss',
#  'glows',
#  'glues',
#  'glugs',
#  'glums',
#  'gnows',
#  'gobos',
#  'godso',
#  'goels',
#  'goers',
#  'goffs',
#  'gogos',
#  'golds',
#  'goles',
#  'golfs',
#  'golps',
#  'gongs',
#  'gonks',
#  'gonys',
#  'goods',
#  'goofs',
#  'googs',
#  'gooks',
#  'gools',
#  'goons',
#  'goops',
#  'goors',
#  'goose',
#  'goosy',
#  'gores',
#  'gorms',
#  'gorps',
#  'gorse',
#  'gorsy',
#  'gosse',
#  'gouks',
#  'gowds',
#  'gowfs',
#  'gowks',
#  'gowls',
#  'gowns',
#  'goxes',
#  'grees',
#  'grens',
#  'grese',
#  'grews',
#  'greys',
#  'grogs',
#  'groks',
#  'gross',
#  'grosz',
#  'grows',
#  'grrls',
#  'grubs',
#  'grues',
#  'gucks',
#  'gudes',
#  'guess',
#  'guffs',
#  'gules',
#  'gulfs',
#  'gulls',
#  'gulps',
#  'gumps',
#  'gunks',
#  'gurls',
#  'gurns',
#  'gursh',
#  'gurus',
#  'gushy',
#  'gusle',
#  'gussy',
#  'guyse',
#  'gybes',
#  'gymps',
#  'gynos',
#  'gypos',
#  'gypsy',
#  'gyres',
#  'gyros',
#  'gyrus',
#  'gyves',
#  'hebes',
#  'hecks',
#  'heeds',
#  'heels',
#  'heles',
#  'hells',
#  'helms',
#  'helos',
#  'helps',
#  'hemes',
#  'hemps',
#  'hends',
#  'herbs',
#  'herds',
#  'heres',
#  'herls',
#  'herms',
#  'herns',
#  'heros',
#  'herse',
#  'hesps',
#  'hexes',
#  'hobos',
#  'hocks',
#  'hocus',
#  'hoers',
#  'hoggs',
#  'hoghs',
#  'hokes',
#  'holds',
#  'holes',
#  'holks',
#  'holms',
#  'holos',
#  'homes',
#  'homos',
#  'honds',
#  'hones',
#  'hongs',
#  'honks',
#  'hoods',
#  'hoofs',
#  'hooks',
#  'hoons',
#  'hoops',
#  'hoors',
#  'hoosh',
#  'hopes',
#  'horks',
#  'horns',
#  'horse',
#  'horsy',
#  'hosed',
#  'hosel',
#  'hosen',
#  'hoser',
#  'hoses',
#  'hosey',
#  'houfs',
#  'hours',
#  'house',
#  'hoves',
#  'howes',
#  'howfs',
#  'howks',
#  'howls',
#  'howso',
#  'hoxes',
#  'hucks',
#  'huers',
#  'huffs',
#  'huhus',
#  'hules',
#  'hulks',
#  'hulls',
#  'humfs',
#  'humps',
#  'humus',
#  'hunks',
#  'hurds',
#  'hurls',
#  'hushy',
#  'husks',
#  'husky',
#  'husos',
#  'hussy',
#  'hwyls',
#  'hyens',
#  'hykes',
#  'hyles',
#  'hymns',
#  'hypes',
#  'hypos',
#  'hyson',
#  'jeels',
#  'jeeps',
#  'jeers',
#  'jefes',
#  'jeffs',
#  'jehus',
#  'jells',
#  'jeons',
#  'jerks',
#  'jesse',
#  'jesus',
#  'jobes',
#  'jocks',
#  'jocos',
#  'joeys',
#  'johns',
#  'jokes',
#  'joles',
#  'jolls',
#  'jomos',
#  'jones',
#  'jongs',
#  'jooks',
#  'jougs',
#  'jouks',
#  'jours',
#  'jowls',
#  'jubes',
#  'jucos',
#  'judos',
#  'jujus',
#  'jukes',
#  'jukus',
#  'jumps',
#  'junks',
#  'jupes',
#  'jures',
#  'juves',
#  'kecks',
#  'keefs',
#  'keeks',
#  'keels',
#  'keens',
#  'keeps',
#  'kells',
#  'kelps',
#  'kembs',
#  'kemps',
#  'kenos',
#  'kerbs',
#  'kerfs',
#  'kerns',
#  'keros',
#  'kexes',
#  'khors',
#  'khuds',
#  'knees',
#  'knobs',
#  'knops',
#  'knosp',
#  'knows',
#  'knubs',
#  'knurs',
#  'kobos',
#  'koels',
#  'koffs',
#  'kohls',
#  'kolos',
#  'konks',
#  'kooks',
#  'kophs',
#  'kores',
#  'koros',
#  'korus',
#  'koses',
#  'kudos',
#  'kudus',
#  'kukus',
#  'kumys',
#  'kurus',
#  'kusso',
#  'kuzus',
#  'kybos',
#  'kyles',
#  'kynds',
#  'kypes',
#  'ledes',
#  'leeks',
#  'leeps',
#  'leers',
#  'leese',
#  'leges',
#  'lehrs',
#  'lemes',
#  'lends',
#  'lenes',
#  'lengs',
#  'lenos',
#  'lense',
#  'leres',
#  'lerps',
#  'lesbo',
#  'leses',
#  'leuds',
#  'leves',
#  'lexes',
#  'lezes',
#  'lobes',
#  'lobos',
#  'lobus',
#  'lochs',
#  'locks',
#  'locos',
#  'locus',
#  'lodes',
#  'loess',
#  'loges',
#  'logos',
#  'lokes',
#  'lolls',
#  'lomes',
#  'longs',
#  'loofs',
#  'looks',
#  'looms',
#  'loons',
#  'loops',
#  'loose',
#  'lopes',
#  'lords',
#  'lores',
#  'losed',
#  'losel',
#  'losen',
#  'loser',
#  'loses',
#  'lossy',
#  'louns',
#  'loups',
#  'lours',
#  'louse',
#  'lousy',
#  'loves',
#  'lowes',
#  'lowns',
#  'lowps',
#  'lowse',
#  'loxes',
#  'lubes',
#  'luces',
#  'lucks',
#  'ludes',
#  'ludos',
#  'luffs',
#  'luges',
#  'lulls',
#  'lulus',
#  'lumps',
#  'lunes',
#  'lungs',
#  'lunks',
#  'lupus',
#  'lures',
#  'lurks',
#  'luser',
#  'lushy',
#  'lusks',
#  'lusus',
#  'luxes',
#  'lymes',
#  'lynes',
#  'lyres',
#  'lysed',
#  'lyses',
#  'lysol',
#  'mebos',
#  'mechs',
#  'mecks',
#  'meeds',
#  'meers',
#  'meffs',
#  'melds',
#  'mells',
#  'memes',
#  'memos',
#  'mends',
#  'menes',
#  'mengs',
#  'mense',
#  'mensh',
#  'menus',
#  'meous',
#  'meows',
#  'mercs',
#  'meres',
#  'merks',
#  'merls',
#  'merse',
#  'mesel',
#  'meses',
#  'meshy',
#  'mesne',
#  'meson',
#  'messy',
#  'meuse',
#  'meves',
#  'mewls',
#  'mezes',
#  'mobes',
#  'mochs',
#  'mocks',
#  'modes',
#  'modus',
#  'moers',
#  'mofos',
#  'mohos',
#  'mohrs',
#  'mojos',
#  'mokes',
#  'mokos',
#  'molds',
#  'moles',
#  'molls',
#  'molys',
#  'momes',
#  'momus',
#  'mongs',
#  'monks',
#  'monos',
#  'moobs',
#  'moods',
#  'mooks',
#  'mools',
#  'moons',
#  'moops',
#  'moors',
#  'moose',
#  'mopes',
#  'mopsy',
#  'mopus',
#  'mores',
#  'morns',
#  'morse',
#  'mosed',
#  'moses',
#  'mosey',
#  'mosks',
#  'mosso',
#  'mossy',
#  'moues',
#  'mouls',
#  'moups',
#  'mouse',
#  'mousy',
#  'moves',
#  'moyls',
#  'mozes',
#  'mozos',
#  'mucks',
#  'mucus',
#  'muffs',
#  'muggs',
#  'mules',
#  'mulls',
#  'mulse',
#  'mulsh',
#  'mumms',
#  'mumps',
#  'mumsy',
#  'mumus',
#  'mungs',
#  'muons',
#  'mures',
#  'murks',
#  'murls',
#  'murrs',
#  'mused',
#  'muser',
#  'muses',
#  'mushy',
#  'musks',
#  'musky',
#  'musos',
#  'musse',
#  'mussy',
#  'muxes',
#  'myops',
#  'myxos',
#  'mzees',
#  'necks',
#  'needs',
#  ...]
