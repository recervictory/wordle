# %%
with open('2315_possible_answers.txt') as fh:
    answer  = fh.readlines()
answer = [line.rstrip('\n') for line in answer]

with open('2315_possible_answers.txt') as fh:
    answer  = fh.readlines()
allowed = [line.rstrip('\n') for line in answer]

# %%
import random
import re
import string
import pandas as pd

class Wardle(object):

    def __init__(self):
        with open('2315_possible_answers.txt') as fh:
            answer  = fh.readlines()
        self.answer = [line.rstrip('\n') for line in answer]

        #print('{0} words added on answer'.format(len(self.answer)))

        with open('12972_allowed_words.txt') as fh:
            allowed  = fh.readlines()
        self.allowed = [line.rstrip('\n') for line in allowed]
        self.allowed_proba = self.createProb(self.allowed )

        #print('{0} words added on allowed'.format(len(self.allowed)))

        self.word = self.wordleWord()
        self.guess_left = 0


        self.passed = self.allowed
        self.gray = ""
        self.green = set()
        self.yellow = ""

        self.wordScores = self.calWordScore(self.passed)
        
        print("Today's Word is *** {0} ***".format(self.word.upper()))

    def createProb(self,wordList):
        l = len(wordList)
        return [1/l] * l
    
    def calWordScore(self,allowed):
        frequency = { ch : [0] * 5 for ch in string.ascii_lowercase}
        for word in allowed:
            for i in range(0,5):
                frequency[word[i]][i] += 1
        
        matrix  = pd.DataFrame(frequency).T
        matrix = matrix/matrix.sum(axis =0)
        #print(matrix)
        matrix = matrix.T.to_dict()

        wordScore = {}
        for word in allowed:
            score = 0
            for i in range(0,5):
                score += matrix[word[i]][i]
            wordScore.update({word: score})
        #print(wordScore)
        return wordScore

    def wordProb(self):
        words = self.wordScores
        allowed = self.passed

        prob = []
        passed = []
        for word in allowed:
            prob.append(self.wordScores[word])
            #prob.append(1 - words[word]/total)
            passed.append(word)
        
        return prob, passed

    def wordleWord(self):
        return random.choice(self.answer)

    def startGuess(self):
        self._wght,self._words = self.wordProb()
        self.passed = [x for _, x in sorted(zip(self._wght, self._words),reverse = True)]
        if self.guess_left % 2 == 0:
            guess = self.passed.pop(0)
        else:
            guess = random.choices(self._words, weights = self._wght, k= 1)[0]
        self.guess_left += 1
        print("{0},{1}".format(guess.upper(),self.wordScores[guess]))
        self.output(guess)


    def output(self,word):
        for chG,chW in zip(word, self.word):
            if chG == chW:
                self.green.add((chW,self.word.index(chW)))
            if chG not in self.word:
                self.gray += chG
            else:
                if chW not in word :
                    self.yellow += chG
        #print(self.gray,self.green,self.yellow,sep='\n')

    def check(self,str, pattern):
        if re.search(pattern, str):
            return True
        else:
            return False

    def chrPresent(self,chrList):
        l = len(self.passed)
        allowed = self.passed
        if chrList == "":
            self.passed = allowed
            return None
        pattern = re.compile('[{0}]'.format(chrList))
        passed = []
        for word in allowed:
            if self.check(word, pattern):
                passed.append(word)
        self.passed = passed
        print(self.yellow)
        #print(100 - round(len(self.passed)/l,3) * 100)

    def chrNotPresent(self,chrList):
        l = len(self.passed)
        allowed = self.passed
        pattern = re.compile('[{0}]'.format(chrList))
        passed = []
        for word in allowed:
            if not self.check(word, pattern):
                passed.append(word)
        self.passed = passed
        print(self.gray)
        #print(100 - round(len(self.passed)/l,3) * 100)
    
    def location(self,greenList,allowed):
        passed = set()
        if greenList == []:
            return allowed
        else:
            ch, loc = greenList[0]
            for word in allowed:
                if word[loc] == ch:
                    passed.add(word)
            return self.location(greenList[1:],list(passed))
    
    def chrLocation(self,greenList):
        l = len(self.passed)
        greenList = list(greenList)
        self.passed = self.location(greenList,self.passed)
        print(self.green)
        #print(100 - round(len(self.passed)/l,3) * 100)

# %%
game = Wardle()
# Out:
# Today's Word is *** REFIT ***

# %%
game.startGuess()
# Out:
# SWOPS,0.5470592769598397

# %%
max(zip(a.values(), a.keys()))
# Out:
# (0.8590148770523396, 'sores')

# %%
sum([0.056887,0.174516,0.095352,0.082864,0.052494])
# Out:
# 0.462113

# %%
count = 0
for i in range(10):
    game =  Wardle()
    while len(game.passed) > 1 and  game.guess_left < 6:
        game.startGuess()


        game.chrLocation(game.green)
        game.chrPresent(game.yellow)
        game.chrNotPresent(game.gray)

        if len(game.passed) == 1:
            #print(game.passed[0].upper())
            #print("competed in {0} trail".format(game.guess_left))
            count += 1
            break


print("accuracy:",count/10)
# Out:
# Today's Word is *** CARVE ***
# SORES,0.8590148770523396
# {('r', 2)}
# e
# sos
# LURVE,0.35766592152933013
# {('v', 3), ('r', 2), ('e', 4)}
# e
# soslu
# CARVE,0.46727819317043084
# {('a', 1), ('r', 2), ('v', 3), ('c', 0), ('e', 4)}
# e
# soslu
# Today's Word is *** FOCUS ***
# SORES,0.8590148770523396
# {('o', 1), ('s', 4)}
# s
# re
# GOOGS,0.6249903646034071
# {('o', 1), ('s', 4)}
# so
# regg
# SOLAS,0.7355276343174286
# {('o', 1), ('s', 4)}
# sos
# reggla
# TOWNS,0.6111153935095969
# {('o', 1), ('s', 4)}
# sos
# regglatwn
# SOOKS,0.7026131195560009
# {('o', 1), ('s', 4)}
# sosso
# regglatwnk
# COUPS,0.6213674554844677
# {('o', 1), ('s', 4)}
# sossoc
# regglatwnkp
# Today's Word is *** AVIAN ***
# SORES,0.8590148770523396
# set()
# sores
# TUNIC,0.30625144530948895
# set()
# i
# sorestuc
# DAILY,0.4680490248978648
# {('i', 2)}
# ia
# sorestucdly
# KAING,0.3562784244199491
# {('i', 2)}
# iaa
# sorestucdlykg
# BAIZA,0.38780544207199563
# {('i', 2)}
# iaaaa
# sorestucdlykgbz
# AJIVA,0.20326832652431975
# {('i', 2), ('a', 0)}
# iaaaaa
# sorestucdlykgbzj
# Today's Word is *** PULSE ***
# SORES,0.8590148770523396
# set()
# s
# or
# BANTS,0.6932089724813073
# set()
# ss
# orbant
# SELES,0.7959608417482464
# {('l', 2)}
# ssse
# orbant
# PILLS,0.6027133276805674
# {('p', 0), ('l', 2)}
# ssses
# orbanti
# PELES,0.741540121791413
# {('p', 0), ('l', 2)}
# sssese
# orbanti
# PELLS,0.6215987050026979
# {('p', 0), ('l', 2)}
# sssesee
# orbanti
# Today's Word is *** PRIME ***
# SORES,0.8590148770523396
# set()
# re
# sos
# EQUAL,0.19548292607723736
# set()
# ree
# sosqual
# HIREE,0.5333384722115162
# {('e', 4)}
# reee
# sosqualh
# FRIZE,0.32660140291374395
# {('i', 2), ('r', 1), ('e', 4)}
# reee
# sosqualhfz
# TRITE,0.4028366607569568
# {('i', 2), ('r', 1), ('e', 4)}
# reee
# sosqualhfztt
# CRIPE,0.37408463732367225
# {('i', 2), ('r', 1), ('e', 4)}
# reeep
# sosqualhfzttc
# Today's Word is *** WILLY ***
# SORES,0.8590148770523396
# set()
# sores
# DAGGA,0.34047637400755415
# set()
# soresdagga
# TINTY,0.41324288907731443
# {('y', 4), ('i', 1)}
# soresdaggatnt
# FILLY,0.377784629615355
# {('y', 4), ('i', 1), ('l', 2)}
# soresdaggatntf
# BILLY,0.40175749633854935
# {('y', 4), ('i', 1), ('l', 2)}
# soresdaggatntfb
# MILKY,0.36444924073074847
# {('y', 4), ('i', 1), ('l', 2)}
# soresdaggatntfbmk
# Today's Word is *** QUERY ***
# SORES,0.8590148770523396
# set()
# sos
# ARGAN,0.2811223309951438
# set()
# r
# sosagan
# PUREE,0.5467509442688661
# {('u', 1)}
# re
# sosaganp
# MUDIR,0.2946889693979804
# {('u', 1)}
# rer
# sosaganpmdi
# CURET,0.4903260618207045
# {('u', 1)}
# rer
# sosaganpmdict
# LURER,0.4595698758960919
# {('u', 1)}
# rerr
# sosaganpmdictl
# Today's Word is *** CLOTH ***
# SORES,0.8590148770523396
# set()
# o
# sres
# BACON,0.3694596469590688
# set()
# oo
# sresban
# COOLY,0.4688969397980421
# {('o', 2), ('c', 0)}
# ool
# sresbany
# CHOOF,0.24982656286132737
# {('o', 2), ('c', 0)}
# oolho
# sresbanyf
# COOPT,0.3974408386649194
# {('o', 2), ('c', 0)}
# oolhoot
# sresbanyfp
# CHOIL,0.29422647036152005
# {('o', 2), ('c', 0)}
# oolhoot
# sresbanyfpi
# Today's Word is *** FLASK ***
# SORES,0.8590148770523396
# set()
# ss
# ore
# SKANK,0.3040160332999306
# {('a', 2), ('k', 4)}
# sssk
# oren
# SMAAK,0.3333076389424188
# {('a', 2), ('k', 4)}
# sssks
# orenm
# STALK,0.31380559623834114
# {('a', 2), ('k', 4)}
# ssskss
# orenmt
# SLACK,0.32151391351268016
# {('a', 2), ('k', 4), ('l', 1)}
# sssksss
# orenmtc
# Today's Word is *** BORAX ***
# SORES,0.8590148770523396
# {('o', 1), ('r', 2)}
# ses
# MORRA,0.41524705156864256
# {('o', 1), ('r', 2)}
# a
# sesm
# FORAY,0.48315732675556927
# {('o', 1), ('a', 3), ('r', 2)}
# a
# sesmfy
# TORAN,0.4404532490557312
# {('o', 1), ('a', 3), ('r', 2)}
# a
# sesmfytn
# DORAD,0.4530178062129037
# {('o', 1), ('a', 3), ('r', 2)}
# a
# sesmfytndd
# BORAK,0.42680952748015105
# {('o', 1), ('a', 3), ('b', 0), ('r', 2)}
# a
# sesmfytnddk
# accuracy: 0.1

# %%
game =  Wardle()
# Out:
# Today's Word is *** BROAD ***

# %%
game.startGuess()

game.chrLocation(game.green)
game.chrPresent(game.yellow)
game.chrNotPresent(game.gray)
if len(game.passed) < 20:
    len(game.passed)
len(game.passed)
# Out:
# BROAD,0.36537423880366915
# {('b', 0), ('d', 4), ('a', 3), ('r', 1), ('o', 2)}
# arardd
# sesmuckptylgif
# 1
